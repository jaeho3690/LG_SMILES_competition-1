# %%
import sys
import os
sys.path.append('..')
from src.config import test_dir,sample_submission_dir 
import matplotlib.pyplot as plt
import pandas as pd
from PIL import Image

# %%
submission_df = pd.read_csv(sample_submission_dir)

# %%
submission_df.head()
# Out:
#     file_name  SMILES
# 0  test_0.png     NaN
# 1  test_1.png     NaN
# 2  test_2.png     NaN
# 3  test_3.png     NaN
# 4  test_4.png     NaN

# %%
images = os.listdir(test_dir)
Image.open(test_dir/images[0])
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300 at 0x7FBC081EC3C8>

# %%
Image.open(test_dir/images[2])
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300 at 0x7FBC081EC1D0>
